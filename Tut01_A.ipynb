# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("https://tinyurl.com/ChrisCoDV/Pages/DailyHits.csv",index_col=0)

# %%
data
# Out:
#              001  002  003  004  005  006  ...  162  163  164  165  166  167
# Date                                       ...
# 2019-01-01  1062   33   67   42    0    4  ...   10    2    2    2    0    0
# 2019-01-02   976   41   72   19    2    0  ...    0    0    0    0    1    3
# 2019-01-03   956   27   71   28    4    6  ...    6    0    0    3    0    0
# 2019-01-04   976   30   57   29    0    0  ...    0    0    0    0    0    7
# 2019-01-05   956   45   65   27    4    1  ...    0    0    0    0    5    2
# ...          ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 2019-12-27  1065   46   76   24    0    0  ...    0    0    0    2    0    0
# 2019-12-28  1135   55   87   41    1    0  ...    0    4    1    1    5    4
# 2019-12-29  1125   64   92   24    0    2  ...    3    0    0    0    0    1
# 2019-12-30  1113   59   68   48    9    7  ...    0   15    5    0    3    3
# 2019-12-31  1073   66   86   23    0    0  ...    0    0    3    0    0    0
#
# ...

# %%
print(data.tail())
print(data.head())
print(data.describe())
# Out:
#              001  002  003  004  005  006  ...  162  163  164  165  166  167
# Date                                       ...
# 2019-12-27  1065   46   76   24    0    0  ...    0    0    0    2    0    0
# 2019-12-28  1135   55   87   41    1    0  ...    0    4    1    1    5    4
# 2019-12-29  1125   64   92   24    0    2  ...    3    0    0    0    0    1
# 2019-12-30  1113   59   68   48    9    7  ...    0   15    5    0    3    3
# 2019-12-31  1073   66   86   23    0    0  ...    0    0    3    0    0    0
#
# [5 rows x 167 columns]
#              001  002  003  004  005  006  ...  162  163  164  165  166  167
# Date                                       ...
# 2019-01-01  1062   33   67   42    0    4  ...   10    2    2    2    0    0
# 2019-01-02   976   41   72   19    2    0  ...    0    0    0    0    1    3
# 2019-01-03   956   27   71   28    4    6  ...    6    0    0    3    0    0
# 2019-01-04   976   30   57   29    0    0  ...    0    0    0    0    0    7
# ...

# %% [markdown]
# 1.The time of the investigation is between  january 1st 2019 to december 31st,2019.
# it has 167 pages .
# The min for page 001 is 906, the max is 1159, the average is 1040.224658.

# %%
data_sort=data.mean()
print(data_sort)
# Out:
# 001    1040.224658
# 002      47.673973
# 003      74.654795
# 004      31.967123
# 005       1.460274
#           ...
# 163       2.389041
# 164       0.986301
# 165       1.876712
# 166       2.646575
# 167       3.276712
# Length: 167, dtype: float64

# %%
data.mean().sort_values()
# Out:
# 101       0.742466
# 081       0.821918
# 079       0.824658
# 160       0.827397
# 059       0.843836
#           ...
# 155      60.775342
# 080      63.991781
# 003      74.654795
# 001    1040.224658
# 015    1279.789041
# Length: 167, dtype: float64

# %% [markdown]
# THE TWO PAGES THAT HAVE THE HIGHEST AVERAGE ARE 015 AND 001

# %%
page_001=data["001"] 
page_001.plot.line()
plt.show()

# %%
page_015=data["015"] 
page_015.plot.line()
plt.show()

# %%
newdata=data.loc[:,["001","015"]]
print(newdata)
# Out:
#              001   015
# Date
# 2019-01-01  1062  1184
# 2019-01-02   976  1266
# 2019-01-03   956  1047
# 2019-01-04   976  1108
# 2019-01-05   956  1214
# ...          ...   ...
# 2019-12-27  1065  1318
# 2019-12-28  1135  1382
# 2019-12-29  1125  1368
# 2019-12-30  1113  1405
# 2019-12-31  1073  1316
#
# [365 rows x 2 columns]

# %%
compare=newdata["001"]>newdata["015"]
# Out:
# Date
# 2019-01-01    False
# 2019-01-02    False
# 2019-01-03    False
# 2019-01-04    False
# 2019-01-05    False
#               ...
# 2019-12-27    False
# 2019-12-28    False
# 2019-12-29    False
# 2019-12-30    False
# 2019-12-31    False
# Length: 365, dtype: bool

# %%
newdata["compare"]=compare
newdata
# Out:
#              001   015  compare
# Date
# 2019-01-01  1062  1184    False
# 2019-01-02   976  1266    False
# 2019-01-03   956  1047    False
# 2019-01-04   976  1108    False
# 2019-01-05   956  1214    False
# ...          ...   ...      ...
# 2019-12-27  1065  1318    False
# 2019-12-28  1135  1382    False
# 2019-12-29  1125  1368    False
# 2019-12-30  1113  1405    False
# 2019-12-31  1073  1316    False
#
# [365 rows x 3 columns]

# %% [markdown]
# one of the pages has more hit than each other except for the month of february, with the precise date of 2019-02-10

# %%
Average=data.mean(axis=1)
newdata["Average"]=Average
print(newdata)
# Out:
#              001   015  compare    Average
# Date
# 2019-01-01  1062  1184    False  17.994012
# 2019-01-02   976  1266    False  18.383234
# 2019-01-03   956  1047    False  16.353293
# 2019-01-04   976  1108    False  16.347305
# 2019-01-05   956  1214    False  17.940120
# ...          ...   ...      ...        ...
# 2019-12-27  1065  1318    False  18.838323
# 2019-12-28  1135  1382    False  19.922156
# 2019-12-29  1125  1368    False  19.592814
# 2019-12-30  1113  1405    False  20.377246
# 2019-12-31  1073  1316    False  19.269461
#
# [365 rows x 4 columns]

# %%
newdata.plot.line()
plt.show()

# %%
new_data01=newdata.iloc[31:59]
new_data01
new_data01.plot.line()
plt.show()
